# %% [markdown]
# # What is Pandas ?
# ---
# Pandas is Extension of Python or you can call Library.
# <pre>
# Pandas is one of the Powerful and Easy to use library primarily used for Data Analysis.
#
# You Can use Pandas to Peform Following Operations.
#
#   1. Data PreProcessing or Data Cleaning
#   2. Data Manipulation
#   3. (Important) Data Analysis.
#
# Data Analysis is a part Decision Science , Data Analysis help us extract insights/patterns/ facts from Data.
#
# these Facts help organisations improve
# Existing services
# Reduce Escalation
# and Design New Products or Services.

# %% [markdown]
# What is the Difference in Numpy & Pandas ?
# ---
# Numpy Provides us Mathematical Functions eg.
# logs/linear eq./ trigonometry etc.
#
# Numpy Provides us Data. Structure i.e ND Array
#
# Numpy Provides us Features/Functions to Create and Manipulate
# MATRIX.
#
# Summary : Numpy is all about fundamental mathematics + Matrix Manipulation.
#
# ---
#
# Pandas is Built on Top of Numpy. it uses ND Array Internally to
# store Data.
#
# Features of ND Array are available in Pandas , not Whole Numpy.(math part)
#
# Pandas has Builtin Analytical Functions that help us Analyse Data and
# Extract Facts/patterns from Data.
#
# Summary: Pandas provides functionatlies primarily aimed at Data
# Analysis.

# %% [markdown]
# Pandas Provides it OWN Data Structure for Storing & Processing Data.
#
# These are
# 1. Series : Series is used for storing , processing and analysing 1D or Linear Data eg. Like list in Python.
#
# 2. DataFrame : DataFrame is used for storing , processing and analysing 2D or Tabular Data like sheet in Excel.

# %%
CricketScore |   Team
 76               ABC
 49               DEF
 22               GHI
 98               JKL
 17               MNO

# %%
# first we must import pandas

import pandas as pd

# %%
# here is a sample marks of  a student in 5 Subjets

marks = [ 82 , 76 , 45 , 98 , 54 ]

# %% [markdown]
# In order to analyse the above python LIST i.e Marks we Must convert the above data into SERIES.
#
# pd.Series() this method lets u convert List to Series.

# %%
mySeries = pd.Series ( marks )

# %%
# what is mySeries ?
type(mySeries)
# Out:
# pandas.core.series.Series

# %%
# what does it contains ?
mySeries
# Out:
# 0    82
# 1    76
# 2    45
# 3    98
# 4    54
# dtype: int64

# %%
mySeries.values
# Out:
# array([82, 76, 45, 98, 54])

# %%
# did u observe ?
type(mySeries.values)
# Out:
# numpy.ndarray

# %%
mySeries.values.<callANy Function of ND Array> !!

# %%
mySeries.values.max()
# Out:
# 98

# %%
# but now realise that u need numpy for additional things

np.median(mySeries.values)

# %% [markdown]
# # How to Create DataFrame using pd.read_csv() Method
# ---
#
# 🏀 NBA
# ---
# Link :
# https://drive.google.com/file/d/1dfXMw5ON1I-IYTMlcwuNg8SC13e3dUwN/view?usp=sharing

# %%
nba = pd.read_csv('nba.csv')

# %%
# what is nba ?
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
# what does it contains ?
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# What to do after the Data has been Loaded ?

# %% [markdown]
# ## Data Inspection
# ---

# %%
# how many rows X Cols are there ?
nba.shape
# Out:
# (458, 9)

# %%
# What are the Columns available ?
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.columns.tolist()
# Out:
# ['Name',
#  'Team',
#  'Number',
#  'Position',
#  'Age',
#  'Height',
#  'Weight',
#  'College',
#  'Salary']

# %%
# what is the datatype of each column ?
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
# Please note : object datatype represents String data in Pandas .
# no string datatype available in Pandas.

# %%
# you can use .describe() to find statistical facts for all numerical columns
nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# Ultimately you can .info() for detailed summary
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Name of Column | Count of Values in Column

# %%
# you can use below expression or function call to find the count of missing (absent) values
# in each column !

nba.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
# you can use .head() function to fetch first 5 rows
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# you can use .tail() to fetch last 5 rows
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
# you can also specify your choice of count of rows
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %% [markdown]
# How to Access a Single Column in a DataFrame ?
#
# ---

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.Name.head(3)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# Name: Name, dtype: object

# %%
nba['Name'].head(3)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# Name: Name, dtype: object

# %%
# What is the Difference in (dot) and [squareBracket] Expression ?

# if there is a column with spaces in its name we cannot use (dot) Expression.
# here is an example

# nba.my college        ❌
# nba['my college']     👌

# %% [markdown]
# # How to Access Multiple Columns in a DataFrame ?
#
# ---

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
#Regular Approach
mycols = ['Name','College','Salary']
nba[ mycols ].head(3)
# Out:
#             Name            College     Salary
# 0  Avery Bradley              Texas  7730337.0
# 1    Jae Crowder          Marquette  6796117.0
# 2   John Holland  Boston University        NaN

# %%
# Direct Expression
nba[ ['Name','College','Salary']].head(3)
# Out:
#             Name            College     Salary
# 0  Avery Bradley              Texas  7730337.0
# 1    Jae Crowder          Marquette  6796117.0
# 2   John Holland  Boston University        NaN

# %% [markdown]
# ## Let us Learn How to Filter Rows in Pandas ?
#
# ---

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# Objective: you are asked to fetch Players of 'Texas' College ONLY.

# %%
# Regular Approach

texasPlayers = nba.College == 'Texas'

nba[ texasPlayers ]
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
# Direct Expression

nba[ nba.College == 'Texas' ]
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
# you can create sub DataFrame

texasHeroes = nba[ nba.College == 'Texas' ]

# %%
texasHeroes
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
# this saves dataframe data in d drive
texasHeroes.to_csv('d:\\texasPlayer.csv')

# %% [markdown]
# # Let us learn how to Handle Multiple Conditions in Pandas
#
# ---

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Objective: you are asked to Find Players from 'Texas' College Playing from 'PG' Position.

# %%
# Regular Approach

c1 = nba.College == 'Texas'

c2 = nba.Position == 'PG'

nba[ c1 & c2 ]     # & is Logical AND
# Out:
#               Name             Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley   Boston Celtics     0.0       PG  25.0    6-2   180.0
# 66     Cory Joseph  Toronto Raptors     6.0       PG  24.0    6-3   190.0
# 384  D.J. Augustin   Denver Nuggets    12.0       PG  28.0    6-0   183.0
#
#     College     Salary
# 0     Texas  7730337.0
# 66    Texas  7000000.0
# 384   Texas  3000000.0

# %%
# Direct Expression

nba[ (nba.College == 'Texas') & (nba.Position == 'PG')]

# please note: enclosing conditions in bracket is Mandatory
# Out:
#               Name             Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley   Boston Celtics     0.0       PG  25.0    6-2   180.0
# 66     Cory Joseph  Toronto Raptors     6.0       PG  24.0    6-3   190.0
# 384  D.J. Augustin   Denver Nuggets    12.0       PG  28.0    6-0   183.0
#
#     College     Salary
# 0     Texas  7730337.0
# 66    Texas  7000000.0
# 384   Texas  3000000.0

# %%
# Using OR Operator

# objective: you are asked to find players playing from either 'SF' or 'C' Position

c1 = nba.Position == 'SF'
c2 = nba.Position == 'C'

nba[ c1 | c2 ].head(10)     # here | is Logical OR
# Out:
#                       Name             Team  Number Position   Age Height  \
# 1              Jae Crowder   Boston Celtics    99.0       SF  25.0    6-6
# 7             Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0
# 10         Jared Sullinger   Boston Celtics     7.0        C  24.0    6-9
# 14            Tyler Zeller   Boston Celtics    44.0        C  26.0    7-0
# 23             Brook Lopez    Brooklyn Nets    11.0        C  28.0    7-0
# 27              Henry Sims    Brooklyn Nets    14.0        C  26.0   6-10
# 32  Thanasis Antetokounmpo  New York Knicks    43.0       SF  23.0    6-7
# 33         Carmelo Anthony  New York Knicks     7.0       SF  32.0    6-8
# 35        Cleanthony Early  New York Knicks    11.0       SF  25.0    6-8
# 38             Robin Lopez  New York Knicks     8.0        C  28.0    7-0
#
#     Weight         College      Salary
# 1    235.0       Marquette   6796117.0
# 7    238.0         Gonzaga   2165160.0
# ...

# %%
b1= nba.Position=="SF"
b2=nba.Position =="C"
nba[b1|b2]
# Out:
#                 Name            Team  Number Position   Age Height  Weight  \
# 1        Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 7       Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 10   Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 14      Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   253.0
# 23       Brook Lopez   Brooklyn Nets    11.0        C  28.0    7-0   275.0
# ..               ...             ...     ...      ...   ...    ...     ...
# 448   Gordon Hayward       Utah Jazz    20.0       SF  26.0    6-8   226.0
# 450       Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451    Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 455     Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456      Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#             College      Salary
# 1         Marquette   6796117.0
# ...

# %%
# using Not Operator

# you can freely use != sign for Not Behavior

# %%
# fetching Rows where Salary Contains NaN

# %%
nba[ nba.Salary.isna() ]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
# Negation i.e ~ Opeartor
# this reverses the given condition

# %%
nba[  ~ nba.Salary.isna() ] # fetch players whose salary is not NaN
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
# # Find Players Whose Age is between 22 to 24

# %%
nba[  nba.Age.between(22,24) ]
# Out:
#                 Name            Team  Number Position   Age Height  Weight  \
# 3        R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 8       Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9       Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10   Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 16      Markel Brown   Brooklyn Nets    22.0       SG  24.0    6-3   190.0
# ..               ...             ...     ...      ...   ...    ...     ...
# 444       Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 446   Derrick Favors       Utah Jazz    15.0       PF  24.0   6-10   265.0
# 447      Rudy Gobert       Utah Jazz    27.0        C  23.0    7-1   245.0
# 449      Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 454        Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
#
#             College      Salary
# 3     Georgia State   1148640.0
# ...

# %% [markdown]
# # Sorting
#
# ---

# %%
# Objective: you are asked to Sort Data BY Salary in Descening Order

# %%
nba.sort_values(by ='Salary', ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %%
# here ascending=True means Ascending ORder , ascending=False means Descending Order

# %% [markdown]
# # Here is an Activity That Makes you Realise how much Pandas you know ?
# ---
#
# <pre>
# You are asked to find the Highest Paid Player from 'Boston Celtics' Team Playing from 'PG' Position .
#
# share the name in CHAT(no Code)

# %%
c1 = nba.Team == 'Boston Celtics'
c2 = nba.Position == 'PG'

bostons = nba [ c1 & c2 ]

# %%
bostons
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 0   Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 8    Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9    Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 11  Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
#
#            College     Salary
# 0            Texas  7730337.0
# 8       Louisville  1824360.0
# 9   Oklahoma State  3431040.0
# 11      Washington  6912869.0

# %%
bostons.sort_values(by='Salary',ascending=False).head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
bostons.sort_values(by='Salary',ascending=False).head(1)['Name']
# Out:
# 0    Avery Bradley
# Name: Name, dtype: object

# %%
bostons.sort_values(by='Salary',ascending=False).head(1)['Name'][0]
# Out:
# 'Avery Bradley'

# %%
data = nba.copy() # creating copy of dataframe

# %%
boston = data[(data.Team == 'Boston Celtics') & (data.Position == 'PG')]
boston.sort_values(by='Salary', ascending=False)
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 0   Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 11  Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 9    Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 8    Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
#
#            College     Salary
# 0            Texas  7730337.0
# 11      Washington  6912869.0
# 9   Oklahoma State  3431040.0
# 8       Louisville  1824360.0

# %%
a=nba.Team == 'Boston Celtics'
b=nba.Position =='PG'

newNBA = nba[ a & b ]

newNBA.sort_values(by ='Salary', ascending=False).head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
# Here is the direct Expression

nba[(nba.Team == 'Boston Celtics') & (nba.Position=='PG')].sort_values(by='Salary',ascending=False).head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %% [markdown]
# # # Here are some Must Know Functions in Pandas
# ---

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
# .nunique() : this function returns Count of Unique Values in a Targeted Columns

nba.Position.nunique()
# Out:
# 5

# %%
# .unique(): this function returns distinct or unique values of Targeted Column
nba.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
nba.Position.unique().tolist()
# Out:
# ['PG', 'SF', 'SG', 'PF', 'C', nan]

# %%
nba.College.nunique()
# Out:
# 118

# %%
# how many teams are there ?

# %%
nba.Team.nunique()
# Out:
# 30

# %%
# what are the name of those teams ?

# %%
nba.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz',
#        nan], dtype=object)

# %%
# value_counts(): this method returns frequency or Occurence Count of each unique value

# %%
len(nba)
# Out:
# 458

# %%
nba.Position.value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
# there are 102 Players playing from 'SG' Position

# %%
# try doing this! find the count of players in Each Team !!

# %%
nba.Team.value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba.Position.value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
# we use normalise=True to convert numbers into %age
# this help us study data by %age distribution
nba.Position.value_counts(normalize=True) * 100
# Out:
# SG    22.319475
# PF    21.881838
# PG    20.131291
# SF    18.599562
# C     17.067834
# Name: Position, dtype: float64

# %%
nba.Position.value_counts(normalize=True).plot(kind='pie');
